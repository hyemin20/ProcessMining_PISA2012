# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('original scoring data.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['time'] = df['time'].astype(float)
df
# Out:
#         Unnamed: 0               ID  cnt  schoolid  StIDStd       event  \
# 0                1  ARE000018904852  ARE       189     4852  START_ITEM
# 1                2  ARE000018904852  ARE       189     4852  ACER_EVENT
# 2                3  ARE000018904852  ARE       189     4852  ACER_EVENT
# 3                4  ARE000018904852  ARE       189     4852  ACER_EVENT
# 4                5  ARE000018904852  ARE       189     4852  ACER_EVENT
# ...            ...              ...  ...       ...      ...         ...
# 322869      322870  USA000007902365  USA        79     2365  ACER_EVENT
# 322870      322871  USA000007902365  USA        79     2365  ACER_EVENT
# 322871      322872  USA000007902365  USA        79     2365  ACER_EVENT
# 322872      322873  USA000007902365  USA        79     2365  ACER_EVENT
# 322873      322874  USA000007902365  USA        79     2365    END_ITEM
#
#           time  event_number     event_value         network   fare_type  \
# ...

# %%
df_action = df[['ID','event_value', 'event_number','instance','credit']]

# %%
df_action['sequence']= ''
df_action["sequence"] = np.nan
# Out:
# <ipython-input-154-bb93eac3a149>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['sequence']= ''
# <ipython-input-154-bb93eac3a149>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action["sequence"] = np.nan

# %%
df_action
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 0       ARE000018904852           Start             1         1       0
# 1       ARE000018904852  country_trains             2         3       0
# 2       ARE000018904852       full_fare             3         4       0
# 3       ARE000018904852           daily             4         7       0
# 4       ARE000018904852             Buy             5        10       0
# ...                 ...             ...           ...       ...     ...
# 322869  USA000007902365     city_subway            16         2       0
# 322870  USA000007902365      concession            17         5       0
# 322871  USA000007902365           daily            18         7       0
# 322872  USA000007902365             Buy            19        10       0
# 322873  USA000007902365             End            20        12       0
#
#         sequence
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==7) and (df_action['instance'][i+3]==11):
        df_action['sequence'][i:i+4]= 'a1'
# Out:
# <ipython-input-157-82f08d41c947>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['sequence'][i:i+4]= 'a1'
# C:\Users\fromd\anaconda3\lib\site-packages\pandas\core\series.py:998: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_with(key, value)
# C:\Users\fromd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==11):
        df_action['sequence'][i:i+6] = 'b1'
# Out:
# <ipython-input-158-d3809225bfa9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['sequence'][i:i+6] = 'b1'

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==10):
        df_action['sequence'][i:i+6] = 'b2'
# Out:
# <ipython-input-159-914a4d7bb5fb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['sequence'][i:i+6] = 'b2'

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==11):
        df_action['sequence'][i:i+5] = 'b3'
# Out:
# <ipython-input-160-e0c0e8384c95>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['sequence'][i:i+5] = 'b3'

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==10):
        df_action['sequence'][i:i+5] = 'b4'
# Out:
# <ipython-input-161-9b42ba0ff421>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['sequence'][i:i+5] = 'b4'

# %%
df_action.tail(50)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 322824  USA000007902381          trip_n             9         8       1
# 322825  USA000007902381          trip_n            10         8       1
# 322826  USA000007902381          trip_n            11         8       1
# 322827  USA000007902381          trip_n            12         8       1
# 322828  USA000007902381          trip_4            13         9       1
# 322829  USA000007902381          trip_n            14         8       1
# 322830  USA000007902381          trip_4            15         9       1
# 322831  USA000007902381          trip_n            16         8       1
# 322832  USA000007902381          trip_n            17         8       1
# 322833  USA000007902381          trip_n            18         8       1
# 322834  USA000007902381          trip_n            19         8       1
# 322835  USA000007902381          trip_4            20         9       1
# ...

# %%
df_action_nonna2 = df_action.fillna('c')

# %%
df_action = df_action_nonna2

# %%
df_action.tail(50)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 322824  USA000007902381          trip_n             9         8       1
# 322825  USA000007902381          trip_n            10         8       1
# 322826  USA000007902381          trip_n            11         8       1
# 322827  USA000007902381          trip_n            12         8       1
# 322828  USA000007902381          trip_4            13         9       1
# 322829  USA000007902381          trip_n            14         8       1
# 322830  USA000007902381          trip_4            15         9       1
# 322831  USA000007902381          trip_n            16         8       1
# 322832  USA000007902381          trip_n            17         8       1
# 322833  USA000007902381          trip_n            18         8       1
# 322834  USA000007902381          trip_n            19         8       1
# 322835  USA000007902381          trip_4            20         9       1
# ...

# %%
df_action['final_sequence'] = ''
df_action["final_sequence"] = np.nan
for i in range(len(df_action)):
    if (df_action['sequence'][i]=='a1') and (df_action['sequence'][i+1]=='a1') and (df_action['sequence'][i+2]=='a1') and (df_action['sequence'][i+3]=='a1'):
        df_action['final_sequence'][i+3]='a1'
# Out:
# <ipython-input-172-6da67d1dbdc2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['final_sequence'][i+3]='a1'
# C:\Users\fromd\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
for i in range(len(df_action)):
    if (df_action['sequence'][i]=='b1') and (df_action['sequence'][i+1]=='b1') and (df_action['sequence'][i+2]=='b1') and (df_action['sequence'][i+3]=='b1') and (df_action['sequence'][i+4]=='b1') and (df_action['sequence'][i+5]=='b1'):
        df_action['final_sequence'][i+5]='b1'
# Out:
# <ipython-input-173-c877b318fa2e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['final_sequence'][i+5]='b1'

# %%
for i in range(len(df_action)):
    if (df_action['sequence'][i]=='b2') and (df_action['sequence'][i+1]=='b2') and (df_action['sequence'][i+2]=='b2') and (df_action['sequence'][i+3]=='b2') and (df_action['sequence'][i+4]=='b2') and (df_action['sequence'][i+5]=='b2'):
        df_action['final_sequence'][i+5]='b2'
# Out:
# <ipython-input-174-7f8bf1ed2876>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['final_sequence'][i+5]='b2'

# %%
for i in range(len(df_action)):
    if (df_action['sequence'][i]=='b3') and (df_action['sequence'][i+1]=='b3') and (df_action['sequence'][i+2]=='b3') and (df_action['sequence'][i+3]=='b3') and (df_action['sequence'][i+4]=='b3'):
        df_action['final_sequence'][i+4]='b3'
# Out:
# <ipython-input-175-a6ea8277a57c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['final_sequence'][i+4]='b3'

# %%
for i in range(len(df_action)):
    if (df_action['sequence'][i]=='b4') and (df_action['sequence'][i+1]=='b4') and (df_action['sequence'][i+2]=='b4') and (df_action['sequence'][i+3]=='b4') and (df_action['sequence'][i+4]=='b4'):
        df_action['final_sequence'][i+4]='b4'
# Out:
# <ipython-input-176-d8a64229f211>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['final_sequence'][i+4]='b4'

# %%
for i in range(len(df_action)):
    if (df_action['sequence'][i]== 'c'):
        df_action['final_sequence'][i]='c'
# Out:
# <ipython-input-177-467f608aca3f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['final_sequence'][i]='c'

# %%
df_action.tail(50)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 322824  USA000007902381          trip_n             9         8       1
# 322825  USA000007902381          trip_n            10         8       1
# 322826  USA000007902381          trip_n            11         8       1
# 322827  USA000007902381          trip_n            12         8       1
# 322828  USA000007902381          trip_4            13         9       1
# 322829  USA000007902381          trip_n            14         8       1
# 322830  USA000007902381          trip_4            15         9       1
# 322831  USA000007902381          trip_n            16         8       1
# 322832  USA000007902381          trip_n            17         8       1
# 322833  USA000007902381          trip_n            18         8       1
# 322834  USA000007902381          trip_n            19         8       1
# 322835  USA000007902381          trip_4            20         9       1
# ...

# %%
idx = df_action[df_action['event_value']=='Start'].index
df_action = df_action.drop(idx)

# %%
idx = df_action[df_action['event_value']=='End'].index
df_action = df_action.drop(idx)

# %%
df_action.tail(50)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 322821  USA000007902381          trip_n             6         8       1
# 322822  USA000007902381          trip_n             7         8       1
# 322823  USA000007902381          trip_n             8         8       1
# 322824  USA000007902381          trip_n             9         8       1
# 322825  USA000007902381          trip_n            10         8       1
# 322826  USA000007902381          trip_n            11         8       1
# 322827  USA000007902381          trip_n            12         8       1
# 322828  USA000007902381          trip_4            13         9       1
# 322829  USA000007902381          trip_n            14         8       1
# 322830  USA000007902381          trip_4            15         9       1
# 322831  USA000007902381          trip_n            16         8       1
# 322832  USA000007902381          trip_n            17         8       1
# ...

# %%
df_action_final = df_action.dropna()

# %%
idx = df_action_final[df_action_final['event_value']=='Start'].index
df_action_final = df_action_final.drop(idx)

# %%
idx = df_action_final[df_action_final['event_value']=='End'].index
df_action_final = df_action_final.drop(idx)

# %%
df_action_final.tail(50)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 322809  USA000007902371      individual             8         6       1
# 322810  USA000007902371          trip_n             9         8       1
# 322811  USA000007902371          trip_4            10         9       1
# 322812  USA000007902371          trip_n            11         8       1
# 322813  USA000007902371          trip_4            12         9       1
# 322814  USA000007902371             Buy            13        10       1
# 322817  USA000007902381     city_subway             2         2       1
# 322818  USA000007902381      concession             3         5       1
# 322819  USA000007902381      individual             4         6       1
# 322820  USA000007902381          trip_n             5         8       1
# 322821  USA000007902381          trip_n             6         8       1
# 322822  USA000007902381          trip_n             7         8       1
# ...

# %%
df_action_final.to_csv('final_final2.csv', index=False)

# %%
for i in range(len(df_action_final)):
    if (df_action_final['ID'][i]==df_action_final['ID'][i+1]) and (df_action_final['final_sequence'][i]== 'c') and (df_action_final['final_sequence'][i+1]=='c'):
        df_action_final.drop(index = i, axis =0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-191-480874cafdfa> in <module>
#       1 for i in range(len(df_action_final)):
# ...

# %% [markdown]
# city_subway 2
# concession 5
# daily 7
# cancel 11
# individual 6
# trip_n 8
# trip_4 9
# Buy 10
#
#
# - 1 city→concession→daily→cancel                      2-5-7-11
# - 2-1 city→concession→individual→trip_n→trip_4→cancel 2-5-6-8-9-11
# - 2-2 city→concession→individual→trip_n→trip_4→Buy    2-5-6-8-9-10
# - 2-3 city→concession→individual→trip_4→cancel        2-5-6-9-11
# - 2-4 city→concession→individual→trip_4→Buy           2-5-6-9-10
