# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn-extra) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn-extra) (1.0.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn-extra) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.1.0)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn_extra.cluster import KMedoids
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (13, 8)
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
original = pd.read_csv('/content/drive/MyDrive/EM:IP/3_Outliers_3_FullC_with_ln_scoring_gender_time_cleaning', sep=',')
original.head()
# Out:
#    Unnamed: 0               ID  cnt    time_a   time_b1   time_b2  time_start  \
# 0           0  ARE000027907117  ARE  2.442347  2.197225  3.594569    1.799397
# 1           1  ARE000011302798  ARE  4.989071  2.104134  0.000000    1.477276
# 2           2  ARE000018804820  ARE  3.837299  2.442347  0.000000    1.554537
# 3           3  ARE000039910042  ARE  2.476538  1.667707  5.239469    1.406565
# 4           4  ARE000006001557  ARE  3.214868  1.568616  3.449988    1.203616
#
#    time_solving  time_total  time_answer  ...  time_avg_btw_events  \
# 0      1.644610    1.855088     1.610540  ...             1.665188
# 1      1.854589    1.873494     1.797899  ...             2.112231
# 2      1.627475    1.724756     1.617663  ...             1.928619
# 3      1.661441    1.708899     1.557544  ...             0.968839
# 4      1.702884    1.720808     1.625493  ...             1.509397
#
#    events_num  sequence  length  credit  OECD  ratio        mean       weight  \
# 0          15       bab       3       1     0   0.64  391.500000  7638.195150
# 1          30       aab       3       1     0   0.37  212.100000  4349.167700
# 2          10        ab       2       1     0   0.28  168.500000  3287.447976
# 3          43     babab       5       1     0   0.37  227.000000  4428.787482
# 4          25      abab       4       1     0   0.61  338.428571  7308.636611
#
#    gender
# 0       2
# 1       2
# 2       1
# 3       1
# 4       2
#
# [5 rows x 25 columns]

# %%
original[original.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, cnt, time_a, time_b1, time_b2, time_start, time_solving, time_total, time_answer, time_irrelevant, time_explore_relevant, time_ticket_explore, time_explore_total, time_avg_explore, time_avg_btw_events, events_num, sequence, length, credit, OECD, ratio, mean, weight, gender]
# Index: []
#
# [0 rows x 25 columns]

# %%
df = original[['ID','time_b1','time_b2','time_total','time_irrelevant','time_ticket_explore','time_avg_btw_events','length']]
df.set_index('ID', inplace=True)
df
# Out:
#                   time_b1   time_b2  time_total  time_irrelevant  \
# ID
# ARE000027907117  2.197225  3.594569    1.855088         1.233613
# ARE000011302798  2.104134  0.000000    1.873494         1.646667
# ARE000018804820  2.442347  0.000000    1.724756         0.859075
# ARE000039910042  1.667707  5.239469    1.708899         1.481118
# ARE000006001557  1.568616  3.449988    1.720808         1.488570
# ...                   ...       ...         ...              ...
# USA000015004612  2.230014  0.000000    1.514410         0.670652
# USA000015004637  2.525729  0.000000    1.636112         0.988202
# USA000007902358  2.631889  0.000000    1.673242         0.628859
# USA000007902371  2.821379  0.000000    1.637354         0.495826
# USA000007902381  1.931521  3.919991    1.708702         1.332673
#
#                  time_ticket_explore  time_avg_btw_events  length
# ID
# ARE000027907117             0.000000             1.665188       3
# ARE000011302798             0.000000             2.112231       3
# ARE000018804820             0.000000             1.928619       2
# ARE000039910042             0.628859             0.968839       5
# ARE000006001557             1.144244             1.509397       4
# ...                              ...                  ...     ...
# USA000015004612             0.000000             1.178655       2
# USA000015004637             0.000000             1.642873       2
# USA000007902358             0.000000             1.984444       2
# USA000007902371             1.136632             1.712979       2
# USA000007902381             1.364138             1.432223       3
#
# [7191 rows x 7 columns]

# %%
df = df[np.isfinite(df).all(1)]
df = df.dropna(axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7191 entries, ARE000027907117 to USA000007902381
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time_b1              7191 non-null   float64
#  1   time_b2              7191 non-null   float64
#  2   time_total           7191 non-null   float64
#  3   time_irrelevant      7191 non-null   float64
#  4   time_ticket_explore  7191 non-null   float64
#  5   time_avg_btw_events  7191 non-null   float64
#  6   length               7191 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 449.4+ KB

# %%
df_2 = df[['time_b1','time_b2','time_total','time_irrelevant','time_ticket_explore','time_avg_btw_events','length']]
df_2
# Out:
#                   time_b1   time_b2  time_total  time_irrelevant  \
# ID
# ARE000027907117  2.197225  3.594569    1.855088         1.233613
# ARE000011302798  2.104134  0.000000    1.873494         1.646667
# ARE000018804820  2.442347  0.000000    1.724756         0.859075
# ARE000039910042  1.667707  5.239469    1.708899         1.481118
# ARE000006001557  1.568616  3.449988    1.720808         1.488570
# ...                   ...       ...         ...              ...
# USA000015004612  2.230014  0.000000    1.514410         0.670652
# USA000015004637  2.525729  0.000000    1.636112         0.988202
# USA000007902358  2.631889  0.000000    1.673242         0.628859
# USA000007902371  2.821379  0.000000    1.637354         0.495826
# USA000007902381  1.931521  3.919991    1.708702         1.332673
#
#                  time_ticket_explore  time_avg_btw_events  length
# ID
# ARE000027907117             0.000000             1.665188       3
# ARE000011302798             0.000000             2.112231       3
# ARE000018804820             0.000000             1.928619       2
# ARE000039910042             0.628859             0.968839       5
# ARE000006001557             1.144244             1.509397       4
# ...                              ...                  ...     ...
# USA000015004612             0.000000             1.178655       2
# USA000015004637             0.000000             1.642873       2
# USA000007902358             0.000000             1.984444       2
# USA000007902371             1.136632             1.712979       2
# USA000007902381             1.364138             1.432223       3
#
# [7190 rows x 7 columns]

# %%
x = df_2.to_numpy()
x = RobustScaler().fit_transform(x)
df_scale = pd.DataFrame(x, columns = df_2.columns, index = df_2.index)
df_scale
# Out:
#                   time_b1   time_b2  time_total  time_irrelevant  \
# ID
# ARE000027907117 -0.111494  0.644486    2.633435         0.696446
# ARE000011302798 -0.250064 -0.640536    2.845464         1.633623
# ARE000018804820  0.253383 -0.640536    1.132037        -0.153341
# ARE000039910042 -0.899709  1.232522    0.949362         1.258008
# ARE000006001557 -1.047211  0.592800    1.086552         1.274917
# ...                   ...       ...         ...              ...
# USA000015004612 -0.062685 -0.640536   -1.291097        -0.580854
# USA000015004637  0.377501 -0.640536    0.110881         0.139633
# USA000007902358  0.535526 -0.640536    0.538604        -0.675679
# USA000007902371  0.817591 -0.640536    0.125183        -0.977516
# USA000007902381 -0.507007  0.760821    0.947096         0.921203
#
#                  time_ticket_explore  time_avg_btw_events  length
# ID
# ARE000027907117             0.000000             0.620707     0.0
# ARE000011302798             0.000000             1.615650     0.0
# ARE000018804820             0.000000             1.207001    -0.5
# ARE000039910042             0.628859            -0.929091     1.0
# ARE000006001557             1.144244             0.273977     0.5
# ...                              ...                  ...     ...
# USA000015004612             0.000000            -0.462124    -0.5
# USA000015004637             0.000000             0.571042    -0.5
# USA000007902358             0.000000             1.331245    -0.5
# USA000007902371             1.136632             0.727071    -0.5
# USA000007902381             1.364138             0.102220     0.0
#
# [7190 rows x 7 columns]

# %%
sns.kdeplot(df['time_b1'])
sns.kdeplot(df['time_b2'])
sns.kdeplot(df['time_total'])
sns.kdeplot(df['time_irrelevant'])
sns.kdeplot(df['time_ticket_explore'])
sns.kdeplot(df['time_avg_btw_events'])
sns.kdeplot(df['length'])

# %%
sns.kdeplot(df_scale['time_b1'])
sns.kdeplot(df_scale['time_b2'])
sns.kdeplot(df_scale['time_total'])
sns.kdeplot(df_scale['time_irrelevant'])
sns.kdeplot(df_scale['time_ticket_explore'])
sns.kdeplot(df_scale['time_avg_btw_events'])
sns.kdeplot(df_scale['length'])

# %%
distortions = []
for i in tqdm(range(1, 15)):
    kmedoids = KMedoids(n_clusters=i, random_state=0).fit(x)
    #inertia가 군집 내의 분산을 의미
    distortions.append(kmedoids.inertia_)

# plot
plt.figure(figsize=(7,5))
plt.plot(range(1, 15), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.title('Elbow Method for Optimal K')
plt.show()
# Out:
# 100%|██████████| 14/14 [00:22<00:00,  1.60s/it]

# %%
num = 5
kmedoids = KMedoids(n_clusters=num, random_state=0).fit(x)
print(kmedoids.labels_)
# Out:
# [0 1 1 ... 1 0 0]

# %%
df_scale['cluster'] = kmedoids.labels_
df_scale
# Out:
#                    time_a   time_b1   time_b2   time_b3  time_total  \
# ID
# ARE000027907117 -0.256351  0.000000  0.000000  1.354784    2.633435
# ARE000011302798  2.200737 -0.138908  0.000000  0.000000    2.845464
# ARE000018804820  1.089504  0.365768  0.000000  0.000000    1.132037
# ARE000039910042 -0.223363 -0.790139  0.000000  0.900318    0.949362
# ARE000006001557  0.488979 -0.938001  0.000000  0.000000    1.086552
# ...                   ...       ...       ...       ...         ...
# USA000015004612 -0.482185  0.048929  0.000000  0.000000   -1.291097
# USA000015004637  0.559925  0.490189  0.000000  0.000000    0.110881
# USA000007902358  0.868479  0.648600  0.000000  0.000000    0.538604
# USA000007902371  0.797984 -3.278668  2.821379  0.000000    0.125183
# USA000007902381 -0.381594 -0.396479  0.000000  0.000000    0.947096
#
#                  time_answer  time_irrelevant  time_explore_relevant  \
# ID
# ARE000027907117     0.842444         0.696446               0.880492
# ARE000011302798     2.441911         1.633623               2.131844
# ARE000018804820     0.903253        -0.153341               0.867389
# ARE000039910042     0.390024         1.258008               0.621128
# ARE000006001557     0.970094         1.274917               1.080478
# ...                      ...              ...                    ...
# USA000015004612    -1.383871        -0.580854              -1.563623
# USA000015004637     0.205151         0.139633               0.154334
# USA000007902358     0.674520        -0.675679               0.580155
# USA000007902371     0.684961        -0.977516               0.485533
# USA000007902381     1.135822         0.921203               1.164176
#
#                  time_avg_explore  time_avg_btw_events  cluster
# ID
# ARE000027907117          0.662073             0.620707        0
# ARE000011302798          2.420866             1.615650        1
# ARE000018804820          1.399531             1.207001        1
# ARE000039910042         -0.584478            -0.929091        2
# ARE000006001557          0.315703             0.273977        0
# ...                           ...                  ...      ...
# USA000015004612         -0.599577            -0.462124        5
# USA000015004637          0.723796             0.571042        4
# USA000007902358          1.171397             1.331245        1
# USA000007902371          1.181665             0.727071        0
# USA000007902381          0.957396             0.102220        0
#
# [7191 rows x 11 columns]

# %%
original['cluster'] = kmedoids.labels_
original
# Out:
#                    ID  cnt    time_a   time_b1   time_b2   time_b3   time_b4  \
# 0     ARE000027907117  ARE  2.442347  2.197225  0.000000  3.594569  0.000000
# 1     ARE000011302798  ARE  4.989071  2.104134  0.000000  0.000000  0.000000
# 2     ARE000018804820  ARE  3.837299  2.442347  0.000000  0.000000  0.000000
# 3     ARE000039910042  ARE  2.476538  1.667707  0.000000  2.388763  2.850707
# 4     ARE000006001557  ARE  3.214868  1.568616  0.000000  0.000000  3.449988
# ...               ...  ...       ...       ...       ...       ...       ...
# 7186  USA000015004612  USA  2.208274  2.230014  0.000000  0.000000  0.000000
# 7187  USA000015004637  USA  3.288402  2.525729  0.000000  0.000000  0.000000
# 7188  USA000007902358  USA  3.608212  2.631889  0.000000  0.000000  0.000000
# 7189  USA000007902371  USA  3.535145  0.000000  2.821379  0.000000  0.000000
# 7190  USA000007902381  USA  2.312535  1.931521  0.000000  0.000000  3.919991
#
#       time_start  time_solving  time_total  ...  events_num  sequence  length  \
# 0       1.799397      1.644610    1.855088  ...          15       bab       3
# 1       1.477276      1.854589    1.873494  ...          30       aab       3
# 2       1.554537      1.627475    1.724756  ...          10        ab       2
# 3       1.406565      1.661441    1.708899  ...          43     babab       5
# 4       1.203616      1.702884    1.720808  ...          25      abab       4
# ...          ...           ...         ...  ...         ...       ...     ...
# 7186    1.339048      1.372307    1.514410  ...           8        ab       2
# 7187    1.394995      1.559028    1.636112  ...          10        ab       2
# 7188    1.446093      1.596503    1.673242  ...           8        ab       2
# 7189    1.268981      1.595709    1.637354  ...          11        ab       2
# 7190    1.255502      1.684682    1.708702  ...          25       bab       3
#
#       credit  OECD  ratio        mean       weight gender  cluster
# 0          1     0   0.64  391.500000  7638.195150      2        0
# 1          1     0   0.37  212.100000  4349.167700      2        1
# 2          1     0   0.28  168.500000  3287.447976      1        1
# 3          1     0   0.37  227.000000  4428.787482      1        2
# 4          1     0   0.61  338.428571  7308.636611      2        0
# ...      ...   ...    ...         ...          ...    ...      ...
# 7186       1     1   0.81  446.571429  9644.068403      1        5
# 7187       1     1   0.38  232.100000  4528.288874      2        4
# 7188       1     1   0.79  430.947368  9433.340364      1        1
# 7189       1     1   0.37  225.600000  4401.473374      1        0
# 7190       1     1   0.38  217.000000  4556.923458      2        0
#
# [7191 rows x 27 columns]

# %%
#original.to_csv('5_NewClustering_2_b1,b2,total,urre,eicketexplore,avg_events,length_8C.csv')

# %% [markdown]
# # 두 변수 상관이 너무 높음

# %%
# 3차원 코드 참고
fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')
colors = ['r','b','g','purple','orange','gray']

for i, color in enumerate(colors):
    x = df_scale[df_scale['cluster'] == i]['time_start']
    y = df_scale[df_scale['cluster'] == i]['avg_time_btw_events']
    z = df_scale[df_scale['cluster'] == i]['length']
    ax.scatter(x,y,z,c=color,marker='o')

ax.set_xlabel('time_start')
ax.set_ylabel('avg_time_btw_events')
ax.set_zlabel('length')
# Out:
# Text(0.5, 0, 'length')
