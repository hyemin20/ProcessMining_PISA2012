# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/EM:IP/정리/최종 데이터 파일/variables/0_StartWith_4_final.csv', sep=',')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['time'] = df['time'].astype(float)
df
# Out:
#         number               ID  cnt  schoolid  StIDStd       event    time  \
# 0            1  ARE000018904852  ARE       189     4852  START_ITEM  1186.7
# 1            2  ARE000018904852  ARE       189     4852  ACER_EVENT  1195.6
# 2            3  ARE000018904852  ARE       189     4852  ACER_EVENT  1202.8
# 3            4  ARE000018904852  ARE       189     4852  ACER_EVENT  1217.2
# 4            5  ARE000018904852  ARE       189     4852  ACER_EVENT  1223.7
# ...        ...              ...  ...       ...      ...         ...     ...
# 313247      16  USA000007902365  USA        79     2365  ACER_EVENT   111.5
# 313248      17  USA000007902365  USA        79     2365  ACER_EVENT   112.0
# 313249      18  USA000007902365  USA        79     2365  ACER_EVENT   113.1
# 313250      19  USA000007902365  USA        79     2365  ACER_EVENT   128.6
# 313251      20  USA000007902365  USA        79     2365    END_ITEM   130.3
#
# ...

# %%
df_action = df[['ID','event_value', 'event_number','instance','credit']]

# %%
df_action['sequence']= ''
df_action["sequence"] = np.nan
df_action
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 0       ARE000018904852           Start             1         1       0
# 1       ARE000018904852  country_trains             2         3       0
# 2       ARE000018904852       full_fare             3         4       0
# 3       ARE000018904852           daily             4         7       0
# 4       ARE000018904852             Buy             5        10       0
# ...                 ...             ...           ...       ...     ...
# 313247  USA000007902365     city_subway            16         2       0
# 313248  USA000007902365      concession            17         5       0
# 313249  USA000007902365           daily            18         7       0
# 313250  USA000007902365             Buy            19        10       0
# 313251  USA000007902365             End            20        12       0
#
#         sequence
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %% [markdown]
# ### a: city→concession→daily→cancel (2, 5, 7, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==7) and (df_action['instance'][i+3]==11):
        df_action['sequence'][i:i+4]= 'a'

# %% [markdown]
# ### b: city-concession-individual-trip4-buy (2, 5, 6, 9, 10)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==10):
        df_action['sequence'][i:i+5] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-buy (2, 5, 6, 9, 8, 9, 10)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==10):
        df_action['sequence'][i:i+7] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-buy (2, 5, 6, 9, 8, 9, 8, 9, 10)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==10):
        df_action['sequence'][i:i+9] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-tripn-trip4-buy (2, 5, 6, 9, 8, 9, 8, 9, 8, 9, 10)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==8) and (df_action['instance'][i+9]==9) and (df_action['instance'][i+10]==10):
        df_action['sequence'][i:i+11] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-tripn-trip4-tripn-trip4-buy (2, 5, 6, 9, 8, 9, 8, 9, 8, 9, 8, 9, 10)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==8) and (df_action['instance'][i+9]==9) and (df_action['instance'][i+10]==8) and (df_action['instance'][i+11]==9) and (df_action['instance'][i+12]==10):
        df_action['sequence'][i:i+13] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-cancel (2, 5, 6, 9, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==11):
        df_action['sequence'][i:i+5] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-cancel (2, 5, 6, 9, 8, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==11):
        df_action['sequence'][i:i+6] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-cancel (2, 5, 6, 9, 8, 9, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==11):
        df_action['sequence'][i:i+7] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-cancel (2, 5, 6, 9, 8, 9, 8, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==11):
        df_action['sequence'][i:i+8] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-cancel (2, 5, 6, 9, 8, 9, 8, 9, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==11):
        df_action['sequence'][i:i+9] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-tripn-cancel (2, 5, 6, 9, 8, 9, 8, 9, 8, 11)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==8)  and (df_action['instance'][i+9]==11):
        df_action['sequence'][i:i+10] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-tripn-trip4-cancel (2, 5, 6, 9, 8, 9, 8, 9, 8, 9, 11)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==8) and (df_action['instance'][i+9]==9) and (df_action['instance'][i+10]==11):
        df_action['sequence'][i:i+11] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-tripn-trip4-tripn-cancel (2, 5, 6, 9, 8, 9, 8, 9, 8, 9, 8, 11)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==8) and (df_action['instance'][i+9]==9) and (df_action['instance'][i+10]==8) and (df_action['instance'][i+11]==11):
        df_action['sequence'][i:i+12] = 'b'

# %% [markdown]
# ### b: city-concession-individual-trip4-tripn-trip4-tripn-trip4-tripn-trip4-tripn-trip4-cancel (2, 5, 6, 9, 8, 9, 8, 9, 8, 9, 8, 9, 11)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==9) and (df_action['instance'][i+4]==8) and (df_action['instance'][i+5]==9) and (df_action['instance'][i+6]==8) and (df_action['instance'][i+7]==9) and (df_action['instance'][i+8]==8) and (df_action['instance'][i+9]==9) and (df_action['instance'][i+10]==8) and (df_action['instance'][i+11]==9) and (df_action['instance'][i+12]==11):
        df_action['sequence'][i:i+13] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-buy (2, 5, 6, 8, 9, 10)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==10):
        df_action['sequence'][i:i+6] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-buy (2, 5, 6, 8, 9, 8, 9, 10)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==10):
        df_action['sequence'][i:i+8] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-tripn-trip4-buy (2, 5, 6, 8, 9, 8, 9, 8, 9, 10)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==8) and (df_action['instance'][i+8]==9)  and (df_action['instance'][i+9]==10):
        df_action['sequence'][i:i+10] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-tripn-trip4-tripn-trip4-buy (2, 5, 6, 8, 9, 8, 9, 8, 9, 8, 9, 10)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==8) and (df_action['instance'][i+8]==9) and (df_action['instance'][i+9]==8) and (df_action['instance'][i+10]==9) and (df_action['instance'][i+11]==10):
        df_action['sequence'][i:i+12] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-cancel (2, 5, 6, 8, 9, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==11):
        df_action['sequence'][i:i+6] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-cancel (2, 5, 6, 8, 9, 8, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==11):
        df_action['sequence'][i:i+7] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-cancel (2, 5, 6, 8, 9, 8, 9, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==11):
        df_action['sequence'][i:i+8] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-tripn-cancel (2, 5, 6, 8, 9, 8, 9, 8, 11)

# %%
for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==8) and (df_action['instance'][i+8]==11):
        df_action['sequence'][i:i+9] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-tripn-trip4-cancel (2, 5, 6, 8, 9, 8, 9, 8, 9, 11)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==8) and (df_action['instance'][i+8]==9)  and (df_action['instance'][i+9]==11):
        df_action['sequence'][i:i+10] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-tripn-trip4-tripn-cancel (2, 5, 6, 8, 9, 8, 9, 8, 9, 8, 11)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==8) and (df_action['instance'][i+8]==9) and (df_action['instance'][i+9]==8) and (df_action['instance'][i+10]==11):
        df_action['sequence'][i:i+11] = 'b'

# %% [markdown]
# ### b: city-concession-individual-tripn-trip4-tripn-trip4-tripn-trip4-tripn-trip4-cancel (2, 5, 6, 8, 9, 8, 9, 8, 9, 8, 9, 11)

# %%
 for i in range(len(df_action)):
    if(df_action['instance'][i]==2) and (df_action['instance'][i+1]==5) and (df_action['instance'][i+2]==6) and (df_action['instance'][i+3]==8) and (df_action['instance'][i+4]==9) and (df_action['instance'][i+5]==8) and (df_action['instance'][i+6]==9) and (df_action['instance'][i+7]==8) and (df_action['instance'][i+8]==9) and (df_action['instance'][i+9]==8) and (df_action['instance'][i+10]==9) and (df_action['instance'][i+11]==11):
        df_action['sequence'][i:i+12] = 'b'

# %%
df_action.tail(50)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 313202  USA000007902371             Buy            13        10       1
# 313203  USA000007902371             End            14        12       1
# 313204  USA000007902381           Start             1         1       1
# 313205  USA000007902381     city_subway             2         2       1
# 313206  USA000007902381      concession             3         5       1
# 313207  USA000007902381      individual             4         6       1
# 313208  USA000007902381          trip_n             5         8       1
# 313209  USA000007902381          trip_4            13         9       1
# 313210  USA000007902381          trip_n            14         8       1
# 313211  USA000007902381          trip_4            15         9       1
# 313212  USA000007902381          trip_n            16         8       1
# 313213  USA000007902381          trip_4            20         9       1
# ...

# %%
# 정답 이외의 행동은 모두 c로 처리
df_action = df_action.fillna('c')

# %% [markdown]
# ### Start, End 삭제

# %%
idx = df_action[df_action['event_value']=='Start'].index
df_action = df_action.drop(idx)

# %%
idx = df_action[df_action['event_value']=='End'].index
df_action = df_action.drop(idx)

# %%
df_action.tail(60)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 313185  USA000007902358      concession             7         5       1
# 313186  USA000007902358      individual             8         6       1
# 313187  USA000007902358          trip_4             9         9       1
# 313188  USA000007902358             Buy            10        10       1
# 313191  USA000007902371     city_subway             2         2       1
# 313192  USA000007902371      concession             3         5       1
# 313193  USA000007902371           daily             4         7       1
# 313194  USA000007902371          Cancel             5        11       1
# 313195  USA000007902371     city_subway             6         2       1
# 313196  USA000007902371      concession             7         5       1
# 313197  USA000007902371      individual             8         6       1
# 313198  USA000007902371          trip_n             9         8       1
# ...

# %%
df_action['final_sequence'] = ''
df_action["final_sequence"] = np.nan
df_action
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 1       ARE000018904852  country_trains             2         3       0
# 2       ARE000018904852       full_fare             3         4       0
# 3       ARE000018904852           daily             4         7       0
# 4       ARE000018904852             Buy             5        10       0
# 7       ARE000018904861  country_trains             2         3       0
# ...                 ...             ...           ...       ...     ...
# 313246  USA000007902365          Cancel            15        11       0
# 313247  USA000007902365     city_subway            16         2       0
# 313248  USA000007902365      concession            17         5       0
# 313249  USA000007902365           daily            18         7       0
# 313250  USA000007902365             Buy            19        10       0
#
#        sequence  final_sequence
# 1             c             NaN
# 2             c             NaN
# ...

# %%
df_action.to_csv('1_GenerateVariables_2_sequence_abs.csv', index=False)

# %% [markdown]
# ### 시퀀스 열 만들기(a, b는 연속으로 중복될 경우 하나만 쓰고, c는 모두 남김; ex. aaabbbbcc인경우 abcc로 만듦)

# %%
df_action = pd.read_csv('/content/1_GenerateVariables_2_sequence_abs.csv')

# %%
df_action.tail(50)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 252260  USA000007902371      individual             8         6       1
# 252261  USA000007902371          trip_n             9         8       1
# 252262  USA000007902371          trip_4            10         9       1
# 252263  USA000007902371          trip_n            11         8       1
# 252264  USA000007902371          trip_4            12         9       1
# 252265  USA000007902371             Buy            13        10       1
# 252266  USA000007902381     city_subway             2         2       1
# 252267  USA000007902381      concession             3         5       1
# 252268  USA000007902381      individual             4         6       1
# 252269  USA000007902381          trip_n             5         8       1
# 252270  USA000007902381          trip_4            13         9       1
# 252271  USA000007902381          trip_n            14         8       1
# ...

# %%
# b 13개짜리 (Buy)-> 마지막 1개만 final_sequence에 남기기
for i in range(len(df_action)-12):
    if (df_action['event_value'][i+12]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['ID'][i+9]==df_action['ID'][i+10]) and (df_action['ID'][i+10]==df_action['ID'][i+11]) and (df_action['ID'][i+11]==df_action['ID'][i+12]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b') and (df_action['sequence'][i+10]=='b') and (df_action['sequence'][i+11]=='b') and (df_action['sequence'][i+12]=='b'):
        df_action['final_sequence'][i+12]='b'

# %%
# b 13개짜리 (Cancel)
for i in range(len(df_action)-12):
    if (df_action['event_value'][i+12]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['ID'][i+9]==df_action['ID'][i+10]) and (df_action['ID'][i+10]==df_action['ID'][i+11]) and (df_action['ID'][i+11]==df_action['ID'][i+12]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b') and (df_action['sequence'][i+10]=='b') and (df_action['sequence'][i+11]=='b') and (df_action['sequence'][i+12]=='b'):
        df_action['final_sequence'][i+12]='b'

# %%
# b 12개짜리 (Buy)
for i in range(len(df_action)-11):
    if (df_action['event_value'][i+11]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['ID'][i+9]==df_action['ID'][i+10]) and (df_action['ID'][i+10]==df_action['ID'][i+11]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b') and (df_action['sequence'][i+10]=='b') and (df_action['sequence'][i+11]=='b'):
        df_action['final_sequence'][i+11]='b'

# %%
# b 12개짜리(Cancel)
for i in range(len(df_action)-11):
    if (df_action['event_value'][i+11]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['ID'][i+9]==df_action['ID'][i+10]) and (df_action['ID'][i+10]==df_action['ID'][i+11]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b') and (df_action['sequence'][i+10]=='b') and (df_action['sequence'][i+11]=='b'):
        df_action['final_sequence'][i+11]='b'

# %%
# b 11개짜리(Buy)
for i in range(len(df_action)-10):
    if (df_action['event_value'][i]=='city_subway') and (df_action['event_value'][i+10]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['ID'][i+9]==df_action['ID'][i+10]) and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b') and (df_action['sequence'][i+10]=='b'):
        df_action['final_sequence'][i+10]='b'

# %%
# b 11개짜리(Cancel)
for i in range(len(df_action)-10):
    if (df_action['event_value'][i]=='city_subway') and (df_action['event_value'][i+10]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['ID'][i+9]==df_action['ID'][i+10]) and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b') and (df_action['sequence'][i+10]=='b'):
        df_action['final_sequence'][i+10]='b'

# %%
# b 10개짜리(Buy)
for i in range(len(df_action)-9):
    if (df_action['event_value'][i+9]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b'):
        df_action['final_sequence'][i+9]='b'

# %%
# b 10개짜리(Cancel)
for i in range(len(df_action)-9):
    if (df_action['event_value'][i+9]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['ID'][i+8]==df_action['ID'][i+9]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b') and (df_action['sequence'][i+9]=='b'):
        df_action['final_sequence'][i+9]='b'

# %%
# b 9개짜리(Buy)
for i in range(len(df_action)-8):
    if (df_action['event_value'][i+8]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b'):
        df_action['final_sequence'][i+8]='b'

# %%
# b 9개짜리(Cancel)
for i in range(len(df_action)-8):
    if (df_action['event_value'][i+8]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['ID'][i+7]==df_action['ID'][i+8]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b') and (df_action['sequence'][i+8]=='b'):
        df_action['final_sequence'][i+8]='b'

# %%
# b 8개짜리(Buy)
for i in range(len(df_action)-7):
    if (df_action['event_value'][i+7]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b'):
        df_action['final_sequence'][i+7]='b'

# %%
# b 8개짜리(Cancel)
for i in range(len(df_action)-7):
    if (df_action['event_value'][i+7]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['ID'][i+6]==df_action['ID'][i+7]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b') and (df_action['sequence'][i+7]=='b'):
        df_action['final_sequence'][i+7]='b'

# %%
# b 7개짜리(Buy)
for i in range(len(df_action)-6):
    if (df_action['event_value'][i+6]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b'):
        df_action['final_sequence'][i+6]='b'

# %%
# b 7개짜리(Cancel)
for i in range(len(df_action)-6):
    if (df_action['event_value'][i+6]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['ID'][i+5]==df_action['ID'][i+6]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b') and (df_action['sequence'][i+6]=='b'):
        df_action['final_sequence'][i+6]='b'

# %%
# b 6개짜리(Buy)
for i in range(len(df_action)-5):
    if (df_action['event_value'][i+5]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b'):
        df_action['final_sequence'][i+5]='b'

# %%
# b 6개짜리(Cancel)
for i in range(len(df_action)-5):
    if (df_action['event_value'][i+5]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['ID'][i+4]==df_action['ID'][i+5]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b') and (df_action['sequence'][i+5]=='b'):
        df_action['final_sequence'][i+5]='b'

# %%
# b 5개짜리(Buy)
for i in range(len(df_action)-4):
    if (df_action['event_value'][i+4]=='Buy') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b'):
        df_action['final_sequence'][i+4]='b'

# %%
# b 5개짜리(Cancel)
for i in range(len(df_action)-4):
    if (df_action['event_value'][i+4]=='Cancel') and (df_action['ID'][i]==df_action['ID'][i+1]) and (df_action['ID'][i+1]==df_action['ID'][i+2]) and (df_action['ID'][i+2]==df_action['ID'][i+3]) and (df_action['ID'][i+3]==df_action['ID'][i+4]) and (df_action['event_value'][i]=='city_subway') and (df_action['sequence'][i]=='b') and (df_action['sequence'][i+1]=='b') and (df_action['sequence'][i+2]=='b') and (df_action['sequence'][i+3]=='b') and (df_action['sequence'][i+4]=='b'):
        df_action['final_sequence'][i+4]='b'

# %%
# a 4개짜리
for i in range(len(df_action)-3):
    if (df_action['sequence'][i]=='a') and (df_action['sequence'][i+1]=='a') and (df_action['sequence'][i+2]=='a') and (df_action['sequence'][i+3]=='a'):
        df_action['final_sequence'][i+3]='a'

# %%
df_action.tail(60)
# Out:
#                      ID     event_value  event_number  instance  credit  \
# 252250  USA000007902358      concession             7         5       1
# 252251  USA000007902358      individual             8         6       1
# 252252  USA000007902358          trip_4             9         9       1
# 252253  USA000007902358             Buy            10        10       1
# 252254  USA000007902371     city_subway             2         2       1
# 252255  USA000007902371      concession             3         5       1
# 252256  USA000007902371           daily             4         7       1
# 252257  USA000007902371          Cancel             5        11       1
# 252258  USA000007902371     city_subway             6         2       1
# 252259  USA000007902371      concession             7         5       1
# 252260  USA000007902371      individual             8         6       1
# 252261  USA000007902371          trip_n             9         8       1
# ...

# %%
# a, b결측제거(=마지막만 남김)
df_without_c = df_action.dropna(axis=0)

# %% [markdown]
# ### c없는 문자열 만들기

# %%
new_stu_id = df_without_c['ID'].unique().tolist()
len(new_stu_id)
# Out:
# 15011

# %%
# 문자열 합치기
full_sequence = []
for i in tqdm(new_stu_id):
    a = df_without_c[df_without_c['ID']==i]
    
    seq1 = a['sequence'].tolist()
    seq2 = ''.join(seq1)
    full_sequence.append(seq2)
# Out:
# 100%|██████████| 15011/15011 [00:30<00:00, 489.82it/s]

# %%
df_seq_no_c = pd.DataFrame({'stu_id':new_stu_id, 'sequence':full_sequence})
df_seq_no_c.tail(20)
# Out:
#                 stu_id sequence
# 14991  USA000010603226       ab
# 14992  USA000010603244        b
# 14993  USA000013003978        b
# 14994  USA000013003967        b
# 14995  USA000008902703        a
# 14996  USA000015804888       ab
# 14997  USA000015804879      bab
# 14998  USA000015804866        b
# 14999  USA000015904912        b
# 15000  USA000015904901     abab
# 15001  USA000010403183       ab
# 15002  USA000013604188        b
# 15003  USA000013604175     abab
# 15004  USA000013604190        b
# 15005  USA000015004612       ab
# 15006  USA000015004637       ab
# 15007  USA000007902358       ab
# 15008  USA000007902371       ab
# 15009  USA000007902381      bab
# 15010  USA000007902365        a

# %%
df_seq_no_c['length'] = ''
df_seq_no_c["length"] = np.nan

# %%
for i in range(len(df_seq_no_c)):
    df_seq_no_c['length'][i] = len(df_seq_no_c['sequence'][i])

# %%
df_seq_no_c.tail(20)
# Out:
#                 stu_id sequence  length
# 14991  USA000010603226       ab     2.0
# 14992  USA000010603244        b     1.0
# 14993  USA000013003978        b     1.0
# 14994  USA000013003967        b     1.0
# 14995  USA000008902703        a     1.0
# 14996  USA000015804888       ab     2.0
# 14997  USA000015804879      bab     3.0
# 14998  USA000015804866        b     1.0
# 14999  USA000015904912        b     1.0
# 15000  USA000015904901     abab     4.0
# 15001  USA000010403183       ab     2.0
# 15002  USA000013604188        b     1.0
# 15003  USA000013604175     abab     4.0
# 15004  USA000013604190        b     1.0
# 15005  USA000015004612       ab     2.0
# 15006  USA000015004637       ab     2.0
# 15007  USA000007902358       ab     2.0
# 15008  USA000007902371       ab     2.0
# 15009  USA000007902381      bab     3.0
# 15010  USA000007902365        a     1.0

# %%
df_seq_no_c.to_csv('1_GenerateVariables_2_sequence_abs_and_length.csv', index=False)

# %% [markdown]
# ### 시퀀스 열 만들기 (a, b, c 포함)

# %%
# for i in range(len(df_action)):
#    if (df_action['sequence'][i]=='c'):
#        df_action['final_sequence'][i]='c'

# %%
# a, b결측제거(=마지막만 남김)
# df = df_action.dropna(axis=0)

# %%
# new_stu_id = df['ID'].unique().tolist()
# len(new_stu_id)

# %%
# 문자열 합치기
# full_sequence = []
# for i in tqdm(new_stu_id):
#    a = df[df['ID']==i]
#    
#    seq1 = a['sequence'].tolist()
#    seq2 = ''.join(seq1)
#    full_sequence.append(seq2)

# %%
# 학생 당 점수 붙이기
# credit = []
# for i in tqdm(new_stu_id):
#    a = df[df['ID']==i]
#    stu_credit = min(a['credit'])
#    credit.append(stu_credit)

# %%
# df_seq = pd.DataFrame({'stu_id':new_stu_id, 'credit':credit, 'sequence':full_sequence})
# df_seq.tail(20)

# %%
# df_seq['length'] = ''
# df_seq["length"] = np.nan

# %%
# for i in range(len(df_seq)):
#    df_seq['length'][i] = len(df_seq['sequence'][i])
