# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
pip install scikit-learn-extra

# %%
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn_extra.cluster import KMedoids
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (13, 8)
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/EM:IP/최종 데이터 파일/variables/1_GenerateVariables_3_merge.csv', index_col = False)
df
# Out:
#        Unnamed: 0               ID  cnt  time_A_total  time_b1  time_b2  \
# 0               1  ARE000018904852  ARE           0.0      0.0      0.0
# 1               2  ARE000018904861  ARE           0.0      0.0      0.0
# 2               3  ARE000018904843  ARE           0.0      0.0      0.0
# 3               4  ARE000018904832  ARE           0.0      0.0      0.0
# 4               5  ARE000040210135  ARE           0.0      0.0      0.0
# ...           ...              ...  ...           ...      ...      ...
# 30448       30449  USA000015004637  USA          25.8     11.5      0.0
# 30449       30450  USA000007902358  USA          35.9     12.9      0.0
# 30450       30451  USA000007902371  USA          33.3     15.8      0.0
# 30451       30452  USA000007902381  USA           9.1      5.9      0.0
# 30452       30453  USA000007902365  USA           7.9      0.0      0.0
#
#        time_B_total  time_start  time_end  time_solving  time_total  credit  \
# ...

# %%
df['cnt'] = df['cnt'].astype(str)
df['oecd'] = df['oecd'].astype(int)
df['credit'] = df['credit'].astype(int)
df['length'] = df['length'].astype(int)
df['time_start'] = df['time_start'].astype(float)
df['time_end'] = df['time_end'].astype(float)
df['time_solving'] = df['time_solving'].astype(float)
df['time_total'] = df['time_total'].astype(float)
df['time_answer'] = df['time_answer'].astype(float)
df['avg_time_btw_events'] = df['avg_time_btw_events'].astype(float)
df
# Out:
#        Unnamed: 0               ID  cnt  time_A_total  time_b1  time_b2  \
# 0               1  ARE000018904852  ARE           0.0      0.0      0.0
# 1               2  ARE000018904861  ARE           0.0      0.0      0.0
# 2               3  ARE000018904843  ARE           0.0      0.0      0.0
# 3               4  ARE000018904832  ARE           0.0      0.0      0.0
# 4               5  ARE000040210135  ARE           0.0      0.0      0.0
# ...           ...              ...  ...           ...      ...      ...
# 30448       30449  USA000015004637  USA          25.8     11.5      0.0
# 30449       30450  USA000007902358  USA          35.9     12.9      0.0
# 30450       30451  USA000007902371  USA          33.3     15.8      0.0
# 30451       30452  USA000007902381  USA           9.1      5.9      0.0
# 30452       30453  USA000007902365  USA           7.9      0.0      0.0
#
#        time_B_total  time_start  time_end  time_solving  time_total  credit  \
# ...

# %%
df_1 = df[['ID', 'cnt', 'time_start', 'time_end', 'time_answer', 'time_not_answer','time_solving', 'time_total', 'events_num', 'avg_time_btw_events', 'length', 'credit', 'oecd']]
df_1.set_index('ID', inplace=True)
df_1
# Out:
#                  cnt  time_start  time_end  time_answer  time_not_answer  \
# ID
# ARE000018904852  ARE         8.9       3.8          0.0             28.1
# ARE000018904861  ARE        26.2       9.9          0.0             22.3
# ARE000018904843  ARE        29.8       9.9          0.0             19.6
# ARE000018904832  ARE        34.4       5.0          0.0             25.4
# ARE000040210135  ARE       143.3      16.9          0.0             21.4
# ...              ...         ...       ...          ...              ...
# USA000015004637  USA        19.8       2.5         37.3              4.4
# USA000007902358  USA        24.7       6.4         48.8              1.4
# USA000007902371  USA        11.9      12.5         49.1              0.9
# USA000007902381  USA        11.3       4.4         15.0             64.7
# USA000007902365  USA        25.3       1.7          7.9             27.7
#
#                  time_solving  time_total  events_num  avg_time_btw_events  \
# ID
# ...

# %%
df_1.to_csv('2_ExploratoryAnalysis_0_start_with_all.csv', index=True)

# %%
df_2 = df_1[df_1['credit'] == 1]

# %%
df_2.to_csv('2_ExploratoryAnalysis_0_start_with_full_credit.csv', index=True)
