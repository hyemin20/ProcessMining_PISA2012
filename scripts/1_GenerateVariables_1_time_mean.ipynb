# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir("D:\HYEM'S\GraduatedSchool\PROJECTS\MyProjects\ProcessMining_PISA2012\datasets")
print(os.getcwd())
# Out:
# D:\HYEM'S\GraduatedSchool\PROJECTS\MyProjects\ProcessMining_PISA2012\datasets

# %%
df_original = pd.read_csv("./0_start_with__original_scored_eventlog.csv")
df_time = pd.read_csv("./1_GenerateVariables_time_1_abs.csv")

# %%
stu_id = df_original['ID'].unique().tolist()

# %%
events_num = []

for i in tqdm(stu_id):
    df_t = df_original[df_original['ID'] == i] 
    
    if max(df_t['event_number']) >= 3:
        length = max(df_t['event_number']) - 3
    else:
        length = 
    
    events_num.append(length)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 30453/30453 [09:27<00:00, 53.68it/s]

# %%
events_num
# Out:
# [3,
#  3,
#  8,
#  3,
#  4,
#  4,
#  0,
#  0,
#  0,
#  3,
#  3,
#  6,
#  2,
#  3,
#  5,
#  9,
#  8,
#  4,
#  4,
#  0,
#  15,
#  3,
#  0,
#  0,
#  3,
#  0,
#  3,
#  0,
#  0,
#  3,
#  3,
#  0,
#  0,
#  0,
#  3,
#  3,
#  3,
#  3,
#  3,
#  0,
#  4,
#  7,
#  3,
#  17,
#  0,
#  0,
#  0,
#  0,
#  5,
#  3,
#  4,
#  31,
#  6,
#  0,
#  8,
#  3,
#  4,
#  0,
#  7,
#  10,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  8,
#  10,
#  3,
#  3,
#  5,
#  4,
#  3,
#  4,
#  3,
#  8,
#  0,
#  0,
#  16,
#  12,
#  4,
#  3,
#  3,
#  3,
#  4,
#  10,
#  3,
#  5,
#  3,
#  3,
#  0,
#  6,
#  0,
#  8,
#  44,
#  4,
#  5,
#  7,
#  4,
#  3,
#  12,
#  4,
#  3,
#  3,
#  9,
#  12,
#  3,
#  6,
#  4,
#  0,
#  3,
#  7,
#  0,
#  0,
#  4,
#  0,
#  5,
#  4,
#  2,
#  3,
#  5,
#  8,
#  7,
#  0,
#  0,
#  0,
#  12,
#  3,
#  3,
#  0,
#  4,
#  0,
#  5,
#  9,
#  3,
#  2,
#  3,
#  3,
#  0,
#  3,
#  0,
#  4,
#  4,
#  4,
#  4,
#  22,
#  3,
#  6,
#  5,
#  3,
#  0,
#  25,
#  4,
#  9,
#  3,
#  0,
#  9,
#  5,
#  5,
#  2,
#  19,
#  8,
#  7,
#  13,
# ...

# %%
df_time['events_num'] = events_num

# %%
df_time['avg_time_btw_events'] = df_time['time_solving'] / df_time['events_num']
df_time
# Out:
#                     ID  cnt  time_A_total  time_b1  time_b2  time_B_total  \
# 0      ARE000018904852  ARE           0.0      0.0      0.0           0.0
# 1      ARE000018904861  ARE           0.0      0.0      0.0           0.0
# 2      ARE000018904843  ARE           0.0      0.0      0.0           0.0
# 3      ARE000018904832  ARE           0.0      0.0      0.0           0.0
# 4      ARE000040210135  ARE           0.0      0.0      0.0           0.0
# ...                ...  ...           ...      ...      ...           ...
# 30448  USA000015004637  USA          25.8     11.5      0.0          11.5
# 30449  USA000007902358  USA          35.9     12.9      0.0          12.9
# 30450  USA000007902371  USA          33.3     15.8      0.0          15.8
# 30451  USA000007902381  USA           9.1      5.9      0.0           5.9
# 30452  USA000007902365  USA           7.9      0.0      0.0           0.0
#
#        time_start  time_end  time_total  credit  time_answer  time_not_answer  \
# ...

# %%
df_time = df_time .loc [df_time ['avg_time_btw_events'].notna()]

# %%
df_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30313 entries, 0 to 30452
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   30313 non-null  object
#  1   cnt                  30313 non-null  object
#  2   time_A_total         30313 non-null  float64
#  3   time_b1              30313 non-null  float64
#  4   time_b2              30313 non-null  float64
#  5   time_B_total         30313 non-null  float64
#  6   time_start           30313 non-null  float64
#  7   time_end             30313 non-null  float64
#  8   time_total           30313 non-null  float64
#  9   credit               30313 non-null  int64
#  10  time_answer          30313 non-null  float64
#  11  time_not_answer      30313 non-null  float64
#  12  time_solving         30313 non-null  float64
#  13  events_num           30313 non-null  int64
#  14  avg_time_btw_events  30313 non-null  float64
# ...

# %%
df_time.to_csv('1_GenerateVariables_time_2_mean.csv', index = False)
